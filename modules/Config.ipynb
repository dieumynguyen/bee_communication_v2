# %%
RANDOM_SEED = 10

### ENVIRONMENT PARAMS ###
X_MIN = -3
X_MAX = 3
DX = 0.01
T_MIN = 0
T_MAX = 5  # 5 for 100 timesteps
DT = 0.05
DECAY = 18.0
DIFFUSION_COEFFICIENT = 0.60

### QUEEN PARAMS ###
QUEEN_X = 0
QUEEN_Y = 0
QUEEN_BIAS_SCALAR = 0.0
QUEEN_EMISSION_FREQUENCY = 1
QUEEN_INITIAL_CONCENTRATION = 0.15

### WORKER PARAMS ###
NUM_WORKERS = 70
WORKER_THRESHOLD = 0.010
WORKER_BIAS_SCALAR = 0.0
WORKER_WAIT_PERIOD = 20
WORKER_STEP_SIZE = 0.05
WORKER_INITIAL_CONCENTRATION = 0.15
WORKER_TRANS_PROB = 0.0

SPACE_CONSTRAINT = 0.85
T_THRESHOLD = 100 #0.005

SAVE_FOLDER = "experiments"
PLOTTING_ON = True

# Video path
VID_PATH = f"{SAVE_FOLDER}/Q{QUEEN_INITIAL_CONCENTRATION}_"
VID_PATH += f"W{WORKER_INITIAL_CONCENTRATION}_"
VID_PATH += f"D{DIFFUSION_COEFFICIENT}_"
VID_PATH += f"T{WORKER_THRESHOLD}_wb{WORKER_BIAS_SCALAR}_"
VID_PATH += f"decay{DECAY}_seed{RANDOM_SEED}.mp4"

# %%
BEE_KEEPER_PARAMS = {
    "bee_path"         : "bee_hist.h5", 
    "environment_path" : "envir_hist.h5"
}

QUEEN_PARAMS  = {
    "num"                : -1,
    "x"                  : QUEEN_X,
    "y"                  : QUEEN_Y,
    "A"                  : QUEEN_INITIAL_CONCENTRATION,
    "wb"                 : QUEEN_BIAS_SCALAR,
    "emission_frequency" : QUEEN_EMISSION_FREQUENCY,
}

ENVIRONMENT_PARAMS = {
    "x_min"      : X_MIN,
    "x_max"      : X_MAX,
    "dx"         : DX,
    "t_min"      : T_MIN,
    "t_max"      : T_MAX,
    "dt"         : DT,
    "D"          : DIFFUSION_COEFFICIENT,
    "decay_rate" : DECAY
}

BEE_PARAMS = {
    "x_min"       : X_MIN,
    "x_max"       : X_MAX,
    "init_stddev" : SPACE_CONSTRAINT,
    "A"           : WORKER_INITIAL_CONCENTRATION,
    "threshold"   : WORKER_THRESHOLD,
    "wb"          : WORKER_BIAS_SCALAR,
    "wait_period" : WORKER_WAIT_PERIOD, 
    "step_size"   : WORKER_STEP_SIZE,
    "trans_prob"  : WORKER_TRANS_PROB
}
