# %%
import h5py
import numpy as np
import glob2
import os
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import json
sns.set(style="ticks")
plt.style.use('seaborn-whitegrid')
# Out:
# /Users/dieumynguyen/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# All params
Q_list = [0.15]
W_list = [0.15]
D_list = [0.6]
T_list = [0.0001, 0.001, 0.01, 0.1, 1.0]
wb_list = [5.0]
decay_list = [18.0]

seed_list = [0, 5, 10, 15, 20]

# %% [markdown]
# ## Plot distance

# %%
with open('distance_data.json') as f:
    distance_data = json.load(f)

# %%
len(distance_data)
# Out:
# 5

# %%
fig, axes = plt.subplots(1, 5, sharex=True, sharey=True, figsize=(12,2))
colors = plt.cm.YlGn(np.linspace(0.3, 1, len(seed_list)))

for data_i, (ax, data) in enumerate(zip(axes, distance_data)):
    for trial_i, trials in enumerate(distance_data[data]):
        trials_list = distance_data[data][trials]
        ax.plot(trials_list, label=f"Seed={seed_list[trial_i]}",
               color=colors[trial_i])       
#         ax.spines['right'].set_visible(False)
#         ax.spines['top'].set_visible(False)
        ax.set_title(f"T={T_list[data_i]}", fontsize=14)
        plt.ylim(0,3)
        plt.xlim(0, len(trials_list))

fig.suptitle(f"Q={Q_list[0]}, W={W_list[0]}, D={D_list[0]}, wb={wb_list[0]}, decay={decay_list[0]}", fontsize=15)
fig.subplots_adjust(top=0.7)   

box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(-2, -0.3),
          fancybox=True, shadow=True, ncol=3)  

# Add x and y labels for all
ax = fig.add_subplot(111, frameon=False)
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('Time', labelpad=15) 
ax.set_ylabel('Distance', labelpad=15)
fig.subplots_adjust(wspace=0.15, hspace=0.2)

plt.savefig("sweep_500time.pdf", bbox_inches='tight')
